# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
for row in rows:
    data = row.find_all('td')
    salary_info = [cell.text for cell in data]
    print(salary_info)
# Out:
# []
# ['技術經理 ', '全職', '8 / 12', '60', '幾乎每天', '13 年', '2,300,000 / 年', '795 元', '2019.03']
# ['軟體工程師 ', '全職', '8 / 8', '40', '偶爾', '1 年', '1,500,000 / 年', '778 元', '2020.10']
# ['市場行銷實習生 ', '實習', '8 / 10', '40', '經常', '-', '150 / 小時', '150 元', '2019.05']
# ['INTERN ', '實習', '8 / 8', '32', '幾乎不', '-', '150 / 小時', '150 元', '2019.01']
# ['RDAA 台北', '兼職(含打工)', '8 / 8', '40', '幾乎不', '-', '220 / 小時', '220 元', '2015.02']
# ['實習生 ', '實習', '8 / 8.5', '24', '幾乎不', '1 年', '150 / 小時', '150 元', '2018.06']
# ['實習生 ', '實習', '8 / 8', '16', '幾乎不', '-', '140 / 小時', '140 元', '2017.04']
# ['行銷企劃人員 ', '約聘雇', '8 / 8', '40', '偶爾', '-', '-', '', '2016.04']
# ['派遣職員 ', '', '8 / 10', '50', '幾乎每天', '-', '-', '', '2016.07']
# ['行銷助理 ', '', '7 / 8', '25', '偶爾', '-', '-', '', '2016.07']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


# page1
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
data = []
for row in rows[1:]:
    cells = row.find_all('td')
    salary_info = [cell.text for cell in cells]
    data.append(salary_info)

# page2
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times?p=2"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
for row in rows[1:]:
    cells = row.find_all('td')
    salary_info = [cell.text for cell in cells]
    data.append(salary_info)

columns = ['職稱', '職務型態', '表訂 / 實際工時', '一週總工時', '加班頻率', '業界工作經歷', '薪資', '時薪', '參考時間']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#             職稱     職務型態 表訂 / 實際工時 一週總工時  加班頻率 業界工作經歷             薪資     時薪  \
# 0        技術經理        全職    8 / 12    60  幾乎每天   13 年  2,300,000 / 年  795 元
# 1       軟體工程師        全職     8 / 8    40    偶爾    1 年  1,500,000 / 年  778 元
# 2     市場行銷實習生        實習    8 / 10    40    經常      -       150 / 小時  150 元
# 3      INTERN        實習     8 / 8    32   幾乎不      -       150 / 小時  150 元
# 4      RDAA 台北  兼職(含打工)     8 / 8    40   幾乎不      -       220 / 小時  220 元
# 5         實習生        實習   8 / 8.5    24   幾乎不    1 年       150 / 小時  150 元
# 6         實習生        實習     8 / 8    16   幾乎不      -       140 / 小時  140 元
# 7      行銷企劃人員       約聘雇     8 / 8    40    偶爾      -              -
# 8        派遣職員              8 / 10    50  幾乎每天      -              -
# 9        行銷助理               7 / 8    25    偶爾      -              -
# 10  Operation               8 / 8    40    偶爾      -              -
#
#        參考時間
# 0   2019.03
# 1   2020.10
# 2   2019.05
# 3   2019.01
# 4   2015.02
# 5   2018.06
# 6   2017.04
# 7   2016.04
# 8   2016.07
# 9   2016.07
# 10  2016.07

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def goodjob_life(url, pages):
    data = []
    for i in range(1, pages+1):
        page = requests.get(url+f'?p={i}')
        soup = BeautifulSoup(page.content, 'html.parser')
        salary_table = soup.find_all('table')[0]
        rows = salary_table.find_all('tr')
        for row in rows[1:]:
            cells = row.find_all('td')
            salary_info = [cell.text for cell in cells]
            data.append(salary_info)
    columns = ['職稱', '職務型態', '表訂 / 實際工時', '一週總工時', '加班頻率', '業界工作經歷', '薪資', '時薪', '參考時間']
    return pd.DataFrame(data, columns=columns)

# goodjob_life('https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times', 2)

# %%
DF = goodjob_life('https://www.goodjob.life/companies/%E5%AF%8C%E9%82%A6%E4%BA%BA%E5%A3%BD%E4%BF%9D%E9%9A%AA%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times', 3)
DF.to_csv('FubonLife_salary_info.csv', index=False, encoding='utf_8_sig')
DF
# Out:
#            職稱     職務型態 表訂 / 實際工時 一週總工時  加班頻率 業界工作經歷             薪資     時薪  \
# 0     資深專員 台北       全職     8 / 8    40    偶爾    7 年     45,000 / 月  280 元
# 1         襄理        全職    8 / 10    50    經常   15 年  1,000,000 / 年  415 元
# 2     理賠人員 台北       全職    8 / 10    50    偶爾    5 年     38,000 / 月  189 元
# 3         專員        全職     8 / 8    40   幾乎不    1 年     30,000 / 月  187 元
# 4   軟體測試人員 內湖       實習     8 / 8    24   幾乎不      -       250 / 小時  250 元
# 5       業務專員        全職     8 / 4    20   幾乎不      -    400,000 / 年  415 元
# 6      實習生 IT       實習     8 / 8    24   幾乎不      -      2,000 / 日  250 元
# 7      軟體工程師        全職   8 / 8.5    42    偶爾      -    650,000 / 年  321 元
# 8       業務實習        實習     8 / 8    20   幾乎不      -       150 / 小時  150 元
# 9         工程        全職     8 / 9    50    經常      -     30,000 / 月  148 元
# 10      行政助理        派遣     8 / 9    45    偶爾    2 年     25,000 / 月  138 元
# 11    業務主管 台中       全職    8 / 14    40  幾乎每天    7 年     80,000 / 月  529 元
# 12        業務        全職     9 / 9    45    偶爾    1 年    500,000 / 年  231 元
# 13      行銷專員        全職   10 / 10    50   幾乎不    1 年  1,000,000 / 年  415 元
# 14      行銷專員        全職    4 / 10    50    經常      -     30,000 / 月  149 元
# 15    國內業務主管        全職    8 / 12    84  幾乎每天    4 年  2,000,000 / 年  483 元
# 16    理賠專員 南區       全職    8 / 10    50  幾乎每天      -     36,000 / 月  179 元
# 17   AG TP858  兼職(含打工)     8 / 6    30   幾乎不    3 年    300,000 / 年  207 元
# 18   行銷專員 行天宮       全職     2 / 4    28    偶爾    1 年    480,000 / 年  348 元
# 19    業務主任 內湖       全職    8 / 11    55  幾乎每天    2 年    600,000 / 年  226 元
# 20      專案副理              8 / 10    50    偶爾      -              -
# 21        專員              8 / 11    55  幾乎每天      -              -
# 22      資深專員               8 / 8    43    偶爾      -              -
#
#        參考時間
# 0   2023.07
# 1   2022.09
# 2   2021.03
# 3   2013.02
# 4   2020.06
# 5   2019.06
# 6   2017.06
# 7   2019.05
# 8   2016.08
# 9   2018.11
# 10  2017.06
# 11  2018.07
# 12  2018.06
# 13  2018.06
# 14  2016.08
# 15  2015.06
# 16  2017.04
# 17  2017.03
# 18  2017.03
# 19  2017.02
# 20  2016.08
# 21  2016.08
# 22  2016.07
