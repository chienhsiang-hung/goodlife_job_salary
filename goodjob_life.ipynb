# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
for row in rows:
    data = row.find_all('td')
    salary_info = [cell.text for cell in data]
    print(salary_info)
# Out:
# []
# ['技術經理 ', '全職', '8 / 12', '60', '幾乎每天', '13 年', '2,300,000 / 年', '795 元', '2019.03']
# ['軟體工程師 ', '全職', '8 / 8', '40', '偶爾', '1 年', '1,500,000 / 年', '778 元', '2020.10']
# ['市場行銷實習生 ', '實習', '8 / 10', '40', '經常', '-', '150 / 小時', '150 元', '2019.05']
# ['INTERN ', '實習', '8 / 8', '32', '幾乎不', '-', '150 / 小時', '150 元', '2019.01']
# ['RDAA 台北', '兼職(含打工)', '8 / 8', '40', '幾乎不', '-', '220 / 小時', '220 元', '2015.02']
# ['實習生 ', '實習', '8 / 8.5', '24', '幾乎不', '1 年', '150 / 小時', '150 元', '2018.06']
# ['實習生 ', '實習', '8 / 8', '16', '幾乎不', '-', '140 / 小時', '140 元', '2017.04']
# ['行銷企劃人員 ', '約聘雇', '8 / 8', '40', '偶爾', '-', '-', '', '2016.04']
# ['派遣職員 ', '', '8 / 10', '50', '幾乎每天', '-', '-', '', '2016.07']
# ['行銷助理 ', '', '7 / 8', '25', '偶爾', '-', '-', '', '2016.07']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


# page1
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
data = []
for row in rows[1:]:
    cells = row.find_all('td')
    salary_info = [cell.text for cell in cells]
    data.append(salary_info)

# page2
url = "https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times?p=2"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
salary_table = soup.find_all('table')[0]
rows = salary_table.find_all('tr')
for row in rows[1:]:
    cells = row.find_all('td')
    salary_info = [cell.text for cell in cells]
    data.append(salary_info)

columns = ['職稱', '職務型態', '表訂 / 實際工時', '一週總工時', '加班頻率', '業界工作經歷', '薪資', '時薪', '參考時間']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#             職稱     職務型態 表訂 / 實際工時 一週總工時  加班頻率 業界工作經歷             薪資     時薪  \
# 0        技術經理        全職    8 / 12    60  幾乎每天   13 年  2,300,000 / 年  795 元
# 1       軟體工程師        全職     8 / 8    40    偶爾    1 年  1,500,000 / 年  778 元
# 2     市場行銷實習生        實習    8 / 10    40    經常      -       150 / 小時  150 元
# 3      INTERN        實習     8 / 8    32   幾乎不      -       150 / 小時  150 元
# 4      RDAA 台北  兼職(含打工)     8 / 8    40   幾乎不      -       220 / 小時  220 元
# 5         實習生        實習   8 / 8.5    24   幾乎不    1 年       150 / 小時  150 元
# 6         實習生        實習     8 / 8    16   幾乎不      -       140 / 小時  140 元
# 7      行銷企劃人員       約聘雇     8 / 8    40    偶爾      -              -
# 8        派遣職員              8 / 10    50  幾乎每天      -              -
# 9        行銷助理               7 / 8    25    偶爾      -              -
# 10  Operation               8 / 8    40    偶爾      -              -
#
#        參考時間
# 0   2019.03
# 1   2020.10
# 2   2019.05
# 3   2019.01
# 4   2015.02
# 5   2018.06
# 6   2017.04
# 7   2016.04
# 8   2016.07
# 9   2016.07
# 10  2016.07

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def goodjob_life(url, pages):
    data = []
    for i in range(1, pages+1):
        page = requests.get(url+f'?p={i}')
        soup = BeautifulSoup(page.content, 'html.parser')
        salary_table = soup.find_all('table')[0]
        rows = salary_table.find_all('tr')
        for row in rows[1:]:
            cells = row.find_all('td')
            salary_info = [cell.text for cell in cells]
            data.append(salary_info)
    columns = ['職稱', '職務型態', '表訂 / 實際工時', '一週總工時', '加班頻率', '業界工作經歷', '薪資', '時薪', '參考時間']
    return pd.DataFrame(data, columns=columns)

# goodjob_life('https://www.goodjob.life/companies/%E5%8F%B0%E7%81%A3%E5%BE%AE%E8%BB%9F%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times', 2)

# %%
DF = goodjob_life('https://www.goodjob.life/companies/%E8%8B%B1%E6%A5%AD%E9%81%94%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8/salary-work-times', 7)
DF.to_csv('Inventec_salary_info.csv', index=False, encoding='utf_8_sig')
DF
# Out:
#             職稱 職務型態  表訂 / 實際工時 一週總工時  加班頻率 業界工作經歷             薪資     時薪  \
# 0     作業員╱包裝員    派遣    12 / 12    60  幾乎每天    1 年       150 / 小時  150 元
# 1     機構工程師 士林   全職      8 / 9    45    經常    6 年     50,000 / 月  277 元
# 2       硬體工程師    全職     8 / 11    55    經常    3 年    700,000 / 年  264 元
# 3     散熱工程師 臺北   全職     8 / 10    50    經常      -     60,000 / 月  299 元
# 4     品保工程師 士林   全職    8 / 8.5    40    偶爾   10 年  1,000,000 / 年  521 元
# ..         ...  ...        ...   ...   ...    ...            ...    ...
# 64      機構工程師    全職     8 / 14    60  幾乎每天    5 年     40,000 / 月  168 元
# 65  軟體設計工程師 桃園   全職      9 / 9    40   幾乎不      -     39,500 / 月  248 元
# 66    韌體設計工程師    全職    8 / 8.5    40    偶爾      -     43,000 / 月  269 元
# 67   機構工程師 士林區   全職     8 / 12    60  幾乎每天    5 年     50,000 / 月  207 元
# 68  軟體工程師 新桃科廠   全職  10 / 10.5    50    經常      -     40,000 / 月  200 元
#
#        參考時間
# 0   2019.10
# 1   2016.10
# 2   2022.04
# 3   2023.06
# 4   2018.09
# ..      ...
# 64  2017.03
# 65  2017.03
# 66  2017.03
# 67  2017.03
# 68  2017.03
#
# [69 rows x 9 columns]

# %%
# tigerairtw api

import requests
import json

url = 'https://api-book.tigerairtw.com/graphql'
myobj = {
  "operationName": "appLiveDailyPrices",
  "variables": json.dumps({
    "input": {
      "sessionId": "657fddd7c62a2b767c036f0b",
      "origin": "OKA",
      "destination": "XX3",
      "userCurrency": "TWD",
      "pricingCurrency": "TWD",
      "since": "2023-12-19",
      "until": "2023-12-23",
      "source": "resultPagePriceBrick"
    }
  }),
  "query": "query appLiveDailyPrices($input: QueryLiveDailyPricesInput!) {\n  appLiveDailyPrices(input: $input) {\n    origin\n    destination\n    date\n    currency\n    amount\n    fareLabels {\n      id\n    }\n  }\n}\n"
}
req = requests.post(url, data=myobj, verify=False)
# Out:
# c:\Users\hsiang.hung\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api-book.tigerairtw.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
req.content
# Out:
# b'{"data":{"appLiveDailyPrices":[{"origin":"OKA","destination":"XX3","date":"2023-12-19","currency":"TWD","amount":3299,"fareLabels":[]},{"origin":"OKA","destination":"XX3","date":"2023-12-20","currency":"TWD","amount":3299,"fareLabels":[]},{"origin":"OKA","destination":"XX3","date":"2023-12-21","currency":"TWD","amount":2899,"fareLabels":[]},{"origin":"OKA","destination":"XX3","date":"2023-12-22","currency":"TWD","amount":3299,"fareLabels":[]},{"origin":"OKA","destination":"XX3","date":"2023-12-23","currency":"TWD","amount":2899,"fareLabels":[]}]}}'
